# %% [markdown]
# # Oppgave 1a)

# %% [markdown]
# Solve analytically the initial value problem
#
# $$
# \frac{d^2 y}{dx^2} = -4 \sin(2x), \quad y(0) = 0, \quad y'(0) = 2
# $$
#
# $$
# \int\frac{d^2 y}{dx^2} = \int -4\sin(2x) dx
# $$
# we can use the standard integral:
#
# $$
# \int\sin(ax)dx = -\frac{1}{a}\cos(ax)
# $$
# a=2
# $$
# y' = \int-4\sin(2x)dx = \frac{4}{2}\cos(2x) + C_1 = 2\cos(2x)+ C_1
# $$
# Then we can use the initial value y'(0)= 2
# $$
# 2\cos(0) + C_1 = 2
# $$
# $$
# 2 + C_1 = 2 \rightarrow C_1 = 0
# $$
# The first derivative is:
# $$
# y'=2\cos(2x)dx
# $$
# we integrate again:
#
# $$
# \int y'= \int 2\cos(2x)dx
# $$
# and use the standard integral:
# $$
# \int\cos(ax)dx = \frac{1}{a}\sin(ax)
# $$
# for a = 2
# $$
# y = \frac{2}{2}\sin(2x) +C_2 = \sin(2x)+ C_2
# $$
# use the initial value y(0)= 0
#
# $$
# \sin(0)+ C_2 = 0 \rightarrow C_2 = 0
# $$
# Thus the final solution is:
#
# $$
# y = \sin(2x)
# $$
